# %%
import pandas as pd 
import os 
import re 
import time
from datetime import datetime
import sqlite3

# Define the root directory where your files are located
root_directory = "Z:/業務部/業務一課/G-報價/1. 外銷/"

def FIND_FOLDER(root):
    FOLDER_PATH = []
    COST_FILE_PATH = []
    # Walk through the directory structure|
    for dirpath, dirnames, _ in os.walk(root):
        for dirname in dirnames:
            if dirname == '2024':
                FOLDER_PATH.append(os.path.join(dirpath, dirname))
    for folder in FOLDER_PATH :
        for dirpath, _, filenames in os.walk(folder):
            COST_FILE_PATH.extend([os.path.join(dirpath, file) for file in filenames if '成本表' in file])

    return FOLDER_PATH, [path for path in COST_FILE_PATH if "~$" not in path]

# Find all folders named "2024"
start = time.time()
FOLDER_2024, COST_2024 = FIND_FOLDER(root_directory)
end = time.time()
print("搜尋共耗費 : {}秒".format(end - start))
# Out:
# 搜尋共耗費 : 63.084352254867554秒

# %%
def NAME_CATEGORY(FILE_PATH) :
    NAME = FILE_PATH.split("\\")[-1]
    CUSTOMER = NAME.split("-")[1]   #客戶代號
    AGENT = NAME.split("-")[2]      #承辦人員
    DATE = NAME.split("-")[3]       #詢價日期
    ORDER_INFO = NAME.split("-")[4] #單號或是對接窗口
    return [CUSTOMER.ljust(6,"0"), AGENT, DATE, ORDER_INFO[1], ORDER_INFO[3:].replace(".xlsx","")]

# %%
def DESCRIPTION_CHINESE(PN_TOTAL) :
    DESCRIPTION = []
    CATOGORY_QUANTITY = []
    for number in range(len(PN_TOTAL) - 1):
        item_num = PN_TOTAL.index[number+1] - PN_TOTAL.index[number]
        CATOGORY_QUANTITY.append(item_num)
    CATOGORY_QUANTITY[0] += 2    
    for number in range(len(CATOGORY_QUANTITY)):
        DESCRIPTION.append([PN_TOTAL.values[number]]*CATOGORY_QUANTITY[number])
    return  [item for i in DESCRIPTION for item in i ]

# %%
def READ_FILE(FILE_PATH) :
    STANDARD_PRODUCT_INFO = list(range(52))
    SHEET_NAME = "成本表 "
    with pd.ExcelFile(FILE_PATH) as MOTHER:
        for i in MOTHER.sheet_names:
            if "成本" in i :
                SHEET_NAME = i
                
        # read file and skip the first row
        ROUGH = pd.read_excel(MOTHER, SHEET_NAME, header=None, skiprows=1, usecols = STANDARD_PRODUCT_INFO) 
        THRESHOLD_Nan = 2                  
        if "品名" not in str(ROUGH.iloc[1, 1]) or "報價日" not in str(ROUGH.iloc[0,1]) or "回饋金" not in str(ROUGH.iloc[2,50]) :
            print("此檔案不合標準規範 : {}".format(FILE_PATH.split("\\")[-1]))
        else:      
        # find quote date
            #print(unicodedata.normalize('NFKC', str(ROUGH.iloc[0, 1])))
            QUOTE_DATE = unicodedata.normalize('NFKC',str(ROUGH.iloc[0, 1])).split(":")[1]  # 報價日
            VALID_DATE = unicodedata.normalize('NFKC',str(ROUGH.iloc[0, 6])).split(":")[1]   # 報價有效日
            VERIFICATION = unicodedata.normalize('NFKC',str(ROUGH.iloc[0, 13])).split(":")[1] # 稽核人
            try:
                NOTE = unicodedata.normalize('NFKC',str(ROUGH.iloc[0, 22])).split(":")[1] # 備註
            except :
                NOTE = None
        # find the product type
            PN_INDEX = ROUGH[ROUGH[ROUGH.columns[1]].astype(str).str.contains('品名', na=False)].index 
            PN_TOTAL = ROUGH[1][PN_INDEX]
            PN_TOTAL = PN_TOTAL._append(pd.Series(["Bottom"],[ROUGH.index[-1]]))
            ROUGH["53"] = DESCRIPTION_CHINESE(PN_TOTAL)   # 新增中文敘述
        # Count NaN values in each row and drop rows with more than 2 NaNs then remove it 
            Nan_DROP = ROUGH[ROUGH.isnull().sum(axis=1) > THRESHOLD_Nan].index
            RAW = ROUGH.drop(Nan_DROP)
        # remove the column name    
            DELETE_ROW = RAW.index[[0]]    
            Nan_rows = RAW[RAW[RAW.columns[0]].isnull()].index
            DELETE_ROW = DELETE_ROW.append(Nan_rows)
            RAW.columns = RAW.iloc[0]           # set column
            CLEAN_SHEET = RAW.drop(DELETE_ROW) # remove the column name and sigature
            CLEAN_SHEET = CLEAN_SHEET.rename(columns = {CLEAN_SHEET.columns[-1]:"中文敘述"})
            CLEAN_SHEET = CLEAN_SHEET.rename(columns = {CLEAN_SHEET.columns[0]:"詢價品項編號"})
            CLEAN_SHEET["詢價單地址"] = [FILE_PATH] * CLEAN_SHEET.shape[0]
            CLEAN_SHEET["日期"] = [NAME_CATEGORY(FILE_PATH)[2]] * CLEAN_SHEET.shape[0]
            CLEAN_SHEET["ORDER_TYPE"] = [NAME_CATEGORY(FILE_PATH)[3]] * CLEAN_SHEET.shape[0]
            CLEAN_SHEET["AGENT"] = [NAME_CATEGORY(FILE_PATH)[1]] * CLEAN_SHEET.shape[0] #製表人
            CLEAN_SHEET["CUSTOMER_CODE"] = [NAME_CATEGORY(FILE_PATH)[0]] * CLEAN_SHEET.shape[0] #客代
            CLEAN_SHEET["ORDER_NUMBER"] = [NAME_CATEGORY(FILE_PATH)[4]] * CLEAN_SHEET.shape[0] #單號
            CLEAN_SHEET["NOTE"] = NOTE
            #print("報價單名字 :{}".format(FILE_PATH.split("\\")[-1]))
            #print("此筆報價共含 :{} 筆產品".format(CLEAN_SHEET.shape[0]))
            return PN_TOTAL, CLEAN_SHEET, QUOTE_DATE, VALID_DATE, VERIFICATION

# %%
def PRODUCT_SUMMARY(PANDAS_SERIES, TOTAL_AMOUNT):
    CUMULATIVE = 0
    for number in range(len(PANDAS_SERIES)-1):
        item_num = PANDAS_SERIES.index[number+1] - PANDAS_SERIES.index[number] - 3
        CUMULATIVE += item_num
        print("{} 此次詢價項次 : {} 項".format(PANDAS_SERIES.values[number], item_num))
    return

# %%
def SCREW_TYPE(PANDA_SERIE):
    pattern = r'[^品名]([^螺絲\s]+)\s*螺絲' 
    type_list = []
    for i in range(len(PANDA_SERIE)):
        match = re.search(pattern, PANDA_SERIE.values[i])
        if match:
            type_list.append(match.group(1).strip())
    return list(set(type_list))

# %%
# 如果檔案未被讀取過則將檔案內的品項加入資料庫
def QUOTATION_INSERT(DATAFRAME, TABLENAME, DBNAME, VERNIER):
    COLUMNS = ['PRODUCT_CODE', 'DRAWING_NUMBER', 'SIZE', 'RECESS_PARTIAL_THREAD',
       'MOQ', 'QUANTITY', 'WEIGHT', 'M_BOX', 'KG_BOX', 'BOX_TYPE', 'BOX_PRICE',
       'WIRE_DIAMETER', 'WIRE_PRICE', 'FORMING_PRICE', 'FORMING_PIECE_WEIGHT',
       'FORMING_TOTAL', 'FORMING_GROSS', 'CUT_SLUTTING_LOSS',
       'CUT_SLUTTING_PRICE_M', 'CUT_SLUTTING_PRICE_KG', 'CUT_SLUTTING_GROSS',
       'HEAT_TREATMENT_LOSS', 'HEAT_TREATMENT_PRICE', 'HEAT_TREATMENT_GROSS',
       'PLATING_LOSS', 'PLATING_PRICE_KG', 'PLATING_GROSS', 'PACKAGE_LOSS',
       'PACKAGE_PRICE', 'PACKAGE_GROSS', 'TRANSACTION_CONDITION',
       'OPERATION_FEE', 'FIRST_GROSS', 'ROLLER_SORTING_LOSS',
       'ROLLER_SORTING_PRICE', 'ROLLER_SORTING_GROSS_KG',
       'ROLLER_SORTING_GROSS_M', 'OPTICAL_SORTING_LOSS',
       'OPTICAL_SORTING_PRICE', 'OPTICAL_SORTING_GROSS_M', 'INTEREST_RATE',
       'INTEREST_GROSS',  'PROFIT_RATE', 'PROFIT_GROSS', 'COLLATED_LOSS', 
        'COLLATED_PRICE', 'COLLATED_GROSS', 'EXCHANGE_RATE', 'EXCHANGE_RATE_GROSS',
       'REBATE', 'TOTAL_PRICE_M', 'DESCRIPTION', 'ORDER_ADDRESS', 'QUOTE_DATE',
       'ORDER_TYPE', "AGENT", "CUSTOMER_CODE", "ORDER_NUMBER", "NOTE" ,"SERIAL_NUMBER"]

    for quote_item in DATAFRAME.index:
        ROW_INSERT = DATAFRAME.loc[quote_item,:].values.flatten().tolist()
        ROW_INSERT.pop(0)
        ROW_INSERT.append(datetime.now().timestamp())
        query = f"INSERT INTO {TABLENAME} ({', '.join(COLUMNS)}) VALUES ({', '.join(['?']*len(ROW_INSERT))});"
        VERNIER.execute(query, ROW_INSERT)
        time.sleep(0.1)

# %%
# 取用database中的list，確認檔案是否已讀取
def CHECK_FILE(DATABASE, TABLE):
    with sqlite3.connect(DATABASE) as connection :
        cursor = connection.cursor()
        # Replace 'your_table_name' and 'your_column_name' with the actual table and column names
        column_name = "FILE_ADDRESS"
        # Check if the value already exists in the specified column
        query = f"SELECT {column_name} FROM {TABLE};"
        #existing_rows = cursor.execute(query).fetchall()
        df = pd.read_sql_query(query, connection)
    return df

# %%
def QUOTATION_ANALYZE(COST_FILE_PATH):
    # 詢價統計表打底
    DATABASE = "Z:\跨部門\共用資料夾\C. 業務部\詢價統計DB\QUOTATION_DATABASE.db"
    ORDER_ADDRESS_LIST = CHECK_FILE(DATABASE, "PRODUCT_ADDRESS_SUMMARY" )
    BASE = pd.DataFrame(columns=["承辦人", "稽核人", "詢價日", "報價日", "有效日", "客戶代號", "詢價單號",
                                "產品類別", "線材價格", "利潤", "匯率", "幣別","詢價重量", "報價產品項次",
                                "下單重量", "接單率", "接單項次", "接單率","客戶訂單編號"])
    for file_path in COST_FILE_PATH:
        if file_path.split("\\")[-1][:3] == "成本表" : 
            INSERT_ROW = []
            try:
                PRODUCT_INFO, DATA_SUM, D1, D2, VER = READ_FILE(file_path)
                if  file_path not in ORDER_ADDRESS_LIST["FILE_ADDRESS"].values :     #如果此成本表不在資料庫中，新增至資料庫
                    print("\n此次更新檔案 : {}\n".format(file_path))
                    with sqlite3.connect(DATABASE) as connection : 
                        cursor = connection.cursor()
                        cursor.execute(f"INSERT INTO PRODUCT_ADDRESS_SUMMARY (FILE_ADDRESS) VALUES (?);"
                                     ,(file_path,)) # 檔案位置資料庫
                        QUOTATION_INSERT(DATA_SUM, "CUSTOMER_PRODUCT_SUMMARY", DATABASE, cursor)#品項資料庫
                else :
                    pass

                QUOTE_NAME = NAME_CATEGORY(file_path.split("\\")[-1])
                INSERT_ROW.append([QUOTE_NAME[1], VER,     #稽核人, 承辦人
                                   QUOTE_NAME[2],  #詢價日
                                   D1, D2,         #報價日, 有效日
                                   QUOTE_NAME[0],  #客戶代號
                                   QUOTE_NAME[4],  #詢價單號
                                   SCREW_TYPE(PRODUCT_INFO),          #產品類別
                                   DATA_SUM["線材\n(元/KG)"].unique(),#線材價格
                                   DATA_SUM["利潤"].unique(),         #利潤
                                   DATA_SUM["匯率"].unique(),         #匯率
                                   DATA_SUM.columns[-2].split("/")[0],#幣別
                                   DATA_SUM["重量(KG)"].sum(),         #詢價重量
                                   DATA_SUM.shape[0],                 #報價產品項次
                                   0, 0, 0, 0, 0])                     #訂單相關
                BASE = pd.concat([pd.DataFrame(INSERT_ROW, columns = BASE.columns), BASE], ignore_index=True)
            except :
                print("\n此檔案未被記錄 : {}\n".format(file_path))
    
    ALL_QUOTE = BASE.sort_values(by = ["詢價日"]).reset_index().drop(columns = "index")
    ALL_QUOTE.to_excel("詢價統計表.xlsx", index = False)
    return ALL_QUOTE

# %%
AAA = QUOTATION_ANALYZE(COST_2024)
# Out:
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/01報價中客人\FUCHS+SANDERS (德國)\2024\20240224 CB\成本表-Fussanders-Wesley-20240229-(E)Draeger.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/01報價中客人\FUCHS+SANDERS (德國)\2024\20240815\成本表-FUCHSSANDERS-Wesley-20240816-(E)Aksoy.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/B03500 Sunco (Japan)\2024\20240117\成本表-B03500-Wesley-20240117-(E)Miki.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/B03500 Sunco (Japan)\2024\20240201-2月牌價\成本表-B03500-Wesley-20240201-(E)FEBRUARY.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/B03500 Sunco (Japan)\2024\20240201-3月牌價\成本表-B03500-Wesley-20240305-(E)March.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/B03500 Sunco (Japan)\2024\20240201-4月牌價\成本表-B03500-Wesley-20240402-(E)April.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/B03500 Sunco (Japan)\2024\20240502-5月牌價\成本表-B03500-Wesley-20240502-(E)April.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/B03500 Sunco (Japan)\2024\20240531-6月牌價\成本表-B03500-Wesley-20240531-(E)June.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/B03500 Sunco (Japan)\2024\20240611 自攻\成本表-B03500-Caysie-20240612-(E)Email.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/B03500 Sunco (Japan)\2024\20240717-7月牌價\成本表-B03500-Caysie-20240717-(E)July.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/B03500 Sunco (Japan)\2024\20240924 MS\成本表-B03500-Caysie-20240924-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/B03500 Sunco (Japan)\2024\20240925-10月牌價\成本表-B03500-Wesley-20240925-(E)Oct.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240101-6000095829 0DSVT\成本表-C00600-Lily-20240101-(S)6000095829.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240108-6000096176 TP\成本表-C00600-Wesley-20240109-(S)6000096176.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240111-6000096385 MS\成本表-C00600-Linda-20240111-(S)6000096385.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240112-6000096408 MS\成本表-C00600-Lily-20240112-(S)6000096408.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240112-PJE (SDS)\成本表-C00600-Lily-20240205-(D)PJE.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240116-TP 7981\成本表-C00600-Lily-20240116-(D)TP7981.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240205-6000097793 Collated\成本表-C00600-Wesley-20240206-(S)600097793.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240216-6000098524 TP 7981\成本表-C00600-Lily-20240116-(D)6000098524.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240216-6000098526 07504K\成本表-C00600-Lily-20240216-(S)6000098526.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240226-6000099112 Stock\成本表-C00600-Lily-20240226-(S)6000099112.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240226-6000099112 Stock\成本表-C00600-Lily-20240308-(S)6000099112 議價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240304-6000099471 TP7981\成本表-C00600-Lily-20240304-(D)6000099471.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240306-SDS w new white box\成本表-C00600-Wesley-20240318-(E)Julia.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240314 6000100090 07504M\成本表-C00600-Lily-2024315-(S)6000100090.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240320 07504K (Price Update)\成本表-C00600-Raymond-20240325-(E)Julia.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 (Ray)'!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240320 07504K (Price Update)\成本表-C00600-Wesely-20240325-(E)Julia.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240320 7504k+serration\成本表-C00600-Lily-20240325-(D)7504k.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240401 6000101105(concrete screw)\成本表-C00600-Wesley-20240401-(D)6000101105.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240422 6000102216\成本表-C00600-Caysie-20240430-(S)6000102216議價.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$112:$119.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240422 6000102216\成本表-C00600-Wesley-20240422-(S)6000102216.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240502 6000102877\成本表-C00600-Ru-20240502-(S)6000102877.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240508 Julia(單支詢價)\成本表-C00600-Glave-20240508-(E)julia.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240527 6000104005\成本表-C00600-Caysie-20240527-(S)6000104005.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240606 6000104763 SDS(7504)\成本表-C00600-Ru-20240607-(S)6000104763.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240611 6000104873\成本表-C00600-Ru-20240612-(S)6000104873.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240620 6000105554 TP7981 7982\成本表-C00600-Caysie-20240620-(S)6000105554.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240626 6000105923 MS\成本表-C00600-Caysie-20240626-(S)6000105923.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240711 6000106762(TP7981, SDS)\成本表-C00600-Caysie-20240711-(S)6000106762自攻 - 議價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240711 6000106762(TP7981, SDS)\成本表-C00600-Caysie-20240711-(S)6000106762自攻.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240711 6000106762(TP7981, SDS)\成本表-C00600-Caysie-20240723-(S)6000106762鑽尾 - 議價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240711 6000106762(TP7981, SDS)\成本表-C00600-Caysie-20240723-(S)6000106762鑽尾.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240729 6000107135(MS)\成本表-C00600-Caysie-20240730-(S)6000107135.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240823 60000108605(MS)\成本表-C00600-Caysie-20240823-(S)6000108605.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240830 Email\成本表-C00600-Caysie-20240830-(S)150M.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240830 Email\成本表-C00600-Caysie-20240830-(S)MOQ不足.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\20240909 6000109459 水泥螺絲\成本表-C00600-Caysie-20240911-(D)6000109459.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230113-(S)6000076233.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230118-(S)6000076238.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230202-(S)6000076967.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230209-(S)6000077874.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230210-(S)6000077958.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230224-(S)6000078639.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230301-(S)6000078765.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230307-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230307-(S)6000079259.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230310-(S)VTEKSH +Flake coating.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230313-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230315-(S)6000079746.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230317-(S)6000079801.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230328-(S)6000080279.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230330-(S)6000080501.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230413-(S)6000081363.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230420-(S)6000080637.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230421-(S)6000080339.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230427-(S)6000082107.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230427-(S)7981CT.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230511-(S)Supracoat 30次酸雨.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230515-(S)6000083071.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230526-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230529-(S)6000083683.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230601-(S)6000083546.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230602-(S)6000083928.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230605-(S)6000084111.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230608-(S)6000084320.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230608-(S)窗戶螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230621-(S)6000085022.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230630-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230707-(S)6000032006.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230717-(S)6000080501(路銹寶加價).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230718-(S)6000085022.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230810-(S)6000087624.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230815-(S)6000080501(變更盒型路銹寶加價).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230905-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230918-(S)6000089713.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20230921-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231002-(S)6000090461.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231016-(S)6000090745.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231030-(S)6000092333.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231106-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231115-(S)6000092563.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231116-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231123-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231127-(S)6000092911.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231128-(S)6000094060.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231128-(S)6000094065.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231128-(S)6000094066.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231128-(S)6000094068.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231128-(S)6000094119.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231201-(S)6000094428.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231206-(S)6000094639.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231207-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231212-(S)6000094951.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231213-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231213-(S)6000094937.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231214-(S)6000095059.xlsx
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231215-(S)6000095126.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-Jen-20231219-(S)6000095029.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220121-(S)6000058266.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220210-(S)6000059369.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220216-(S)007981001005505003.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220216-(S)6000059717.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220216-(S)6000059742.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220301-(S)DIN7500(20220413).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220301-(S)DIN7500.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220324-(S)6000061904.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220331-(E)PJE(Frederik).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220406-(S)6000062764.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220412-(S)6000062922.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220413-(S)6000063005.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220414-(S)6000063080.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220419-(S)6000063163.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220422-(S)6000063348.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220425-(S)6000063511.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220426-(S)6000063578.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220426-(S)6000063588.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220428-(S)6000063791.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220504-(S)6000064010.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220510-(S)JVP-7504M.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220516-(S)6000064640.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220524-(S)6000065129.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220608-(S)6000065970水泥螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220616-(S)6000065525.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220630-(E)006928F.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220630-(E)6000063080.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220708-(S)6000067680.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220725-(S)6000068432.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220801-(S)6000068731.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220804-(S)6000068997.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220822-(S)6000069583.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220826-(S)6000069930.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20220914-(S)6000070835.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221007-(S)ISO7045.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221014-(S)6000072635.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221020-(S)6000072899.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221020-(S)6000072998.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221026-(S)6000073179.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221028-(S)6000073382.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221110-(S)07981.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221201-(S)6000074199.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221222-(S)6000075687.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221226-(S)6000075723.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\比利時\2024\REMAKE\成本表-C00600-ShunYuan-20221229-(S)6000075819.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240117 6000096716  鑽尾螺絲Stock\成本表-C00600-Linda-20240117-(S)6000096716.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240201 6000097587 SDS\成本表-C00600-Lily-20240201-(S)6000097587.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240312 6000099850 Stock\成本表-C00600-Wesley-20240312-(E)6000099850 議價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240312 6000099850 Stock\成本表-C00600-Wesley-20240312-(E)6000099850.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240312 6000099902 SDS+EPDM\成本表-C00600-Lily-20240312-(S)6000099902.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240312 6000099913 TP\成本表-C00600-Wei-20240314(6000099913) - 複製.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240328 6000100866 ZBG165 roofing\成本表-C00600-Wesley-20240328-(S)6000100866.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240417 6000101916 SDS+EPDM\成本表-C00600-RU-20240417-(S)6000101916.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240513 6000103299 DW\成本表-C00600-Ru-20240513-(S)6000103299.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240520 6000103580 SDS\成本表-C00600-Caysie-20240520-(S)6000103580.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240524 6000103880 DW\成本表-C00600-Ru-20240513-(S)6000103299.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240624 6000105805 SDS\成本表-C00600-Caysie-20240624-(S)6000105805.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240709 6000406608 SDS\成本表-C00600-Caysie-20240709-(S)6000106608.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240712 6000106433(washer)\成本表-C00600-Wesley-20240712-(S)6000106433.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240716 6000106746 水泥螺絲\成本表-C00600-Glave-20240716-(D)6000106746.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240813 6000108208 DW\成本表-C00600-Caysie-20240814-(S)6000108208.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240820 6000108381(SDS)\成本表-C00600-Caysie-20240820-(S)6000108381.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240913 6000109782 SDS\成本表-C00600-Caysie-20240913-(S)6000109782.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240916 6000109820 SDS+EPDM\成本表-C00600-Wesley-20240916-(S)6000109820.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240920 07504K\成本表-C00600-Wesley-20240920-(E)Julia.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240920 6000110106\成本表-C00600-Wesley-20240920-(S)6000110106.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20240920 VTEKST7504\成本表-C00600-Wesley-20240920-(E)VTEKST.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\20241007 6000110970 水泥螺絲\成本表-C00600-Caysie-20241007-(S)6000110970.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230117-(S)6000076456.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230130-(S)6000077190.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230130-(S)6000077241(新增品項).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230130-(S)6000077241.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230204-(S)6000077626.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230317-(S)6000079804.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230511-(S)6000082857.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230517-(S)6000083202.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230524-(S)6000075094(06客人).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230524-(S)6000083493(06客人).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230525-(S)6000075094(06客人).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230526-(S)6000083573.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230608-(S)6000084318.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230905-(S)6000088815.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20230912-(S)6000089229.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20231109-(S)6000092911.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20231221-(S)6000095382.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C00600-Jen-20231225-(S)6000095573.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C033-ShunYuan-20220510-(S)6000064311.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C033-ShunYuan-20220510-(S)6000064326.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C033-ShunYuan-20220511-(S)6000064315.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C033-ShunYuan-20220602-(S)6000065759.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C033-ShunYuan-20220913-(S)6000070724.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C00600 pgb\波蘭\2024\REMAKE\成本表-C033-ShunYuan-20221207-(S)6000075094.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230118-(S)42689.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230118-(S)42694.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230118-(S)42699.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230118-(S)42704.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230118-(S)42711.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230118-(S)42739.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230118-(S)42746.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230118-(S)42753.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230118-(S)42760.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230306-(S)43185.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230306-(S)43242.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230307-(S)43259.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230307-(S)43289.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230308-(S)43378.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230308-(S)43438.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230308-(S)43445.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230324-(S)43563.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230414-(S)43699.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230414-(S)43732.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230414-(S)43742.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230414-(S)43924.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230417-(S)43828.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230510-(S)43289.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230511-(S)43828.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230531-(S)43699.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230612-(S)44676.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230613-(S)44724.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230721-(S)45555.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230731-(S)45955.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20230906-(S)46120.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20231018-(S)46906.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20231218-(S)47123.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-Jen-20231218-(S)47130.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-ShunYuan-20221010-(S)42158.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-ShunYuan-20221010-(S)42165.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-ShunYuan-20221011-(S)42295(10%).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-ShunYuan-20221011-(S)42295(15%).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-ShunYuan-20221011-(S)42295(20%).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-ShunYuan-20221201-(S)42481.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-ShunYuan-20221201-(S)42491.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-ShunYuan-20221201-(S)42498.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-ShunYuan-20221201-(S)42505.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01000 Ambrovit\2024\REMAKE\成本表-C01000-ShunYuan-20221201-(S)42530.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01100 Interfix\2024\20240205\成本表-C01101-Linda-20240201-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01100 Interfix\2024\20240821\成本表-C01101-Caysie-20240821-(E)Edward議價 - 複製.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01100 Interfix\2024\20240821\成本表-C01101-Caysie-20240821-(E)Edward議價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01100 Interfix\2024\20240821\成本表-C01101-Wesley-20240821-(E)Edward.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01100 Interfix\2024\REMAKE\成本表-C01101-Jen-20230620-(S)Readyfix.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01500 RUFAST BV (匯率29.5)\2024\REMAKE\成本表-C01500-Jen-20230220-(S)塑板螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01700 EJOT\2024\20240829 TP\成本表-C01700-Glove-20240830-(D)Email自攻.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01700 EJOT\2024\REMAKE\成本表-C01700-Jen-20230427-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01700 EJOT\2024\REMAKE\成本表-C01700-Jen-20230522-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01700 EJOT\2024\REMAKE\成本表-C01700-Jen-20230713-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01700 EJOT\2024\REMAKE\成本表-C01700-Jen-20231128-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240105 7002167546 塑板螺絲 89096\成本表-C01900-Linda-20240105-(D)7002167546.xlsx
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240108 6000925147 機械螺絲\成本表-C01900-Linda-20240108-(S)6000925147.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240108 7002168128 (客圖)D7996\成本表-C01900-Linda-20240124-(D)7002168128.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240109 7002168538 機械螺絲 D7985\成本表-C01900-Linda-20240109-(D)7002168538.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240109 7002168655 (客圖)機械螺絲\成本表-C01900-Lily-20240222-(D)7002168655-追加項次13 .xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240109 7002168655 (客圖)機械螺絲\成本表-C01900-Linda-20240124-(D)7002168655-追加項次1.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240109 7002168655 (客圖)機械螺絲\成本表-C01900-Linda-20240124-(D)7002168655.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240109 7002168811 (客圖)自攻螺絲\成本表-C01900-Linda-20240123-(D)7002168811.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240110 7002169496 塑板螺絲 R89096\成本表-C01900-Linda-20240110-(D)7002169496.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240112 6000926156 塑板螺絲\成本表-C01900-Linda-20240112-(S)6000926156.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240112 6000926158 塑板螺絲(專案906)\成本表-C01900-Linda-20240112-(S)6000926158.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240115 7002171224 (客圖)\成本表-C01900-Wesley-20240220-(D)7002171224.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240115 7002171384 三角牙.鑽尾\成本表-C01900-Linda-20240115-(D)7002171384.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240116 6000926642 乾牆螺絲(專案906.907.908)\成本表-C01900-Linda-20240116-(S)6000926642(專案906).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240116 6000926642 乾牆螺絲(專案906.907.908)\成本表-C01900-Linda-20240116-(S)6000926642(專案906-RAPTOR).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240116 6000926642 乾牆螺絲(專案906.907.908)\成本表-C01900-Linda-20240116-(S)6000926642(專案907).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240116 6000926642 乾牆螺絲(專案906.907.908)\成本表-C01900-Linda-20240116-(S)6000926642(專案908).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240116 7002171636 塑板螺絲 R89098\成本表-C01900-Linda-20240116-(D)7002171636.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240116 7002171639 塑板螺絲 R89098\成本表-C01900-Linda-20240116-(D)7002171639.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240116 7002172199 塑板螺絲 R89097\成本表-C01900-Linda-20240116-(D)7002172199.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240116 7002172204 塑板螺絲 R88095\成本表-C01900-Linda-20240116-(D)7002172204.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240122 7002174945 塑板螺絲 R89097\成本表-C01900-Linda-20240123-(D)7002174945.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240123 7002175729 (客圖)塑板螺絲 R88097\成本表-C01900-Linda-20240124-(D)7002175729.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240125 7002177274 三角牙 D7500CT\成本表-C01900-Linda-20240125-(D)7002177274.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240126 7002178234 塑板螺絲 R89098\成本表-C01900-Linda-20240126-(D)7002178234.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240129 6000928456 機械螺絲 D963\成本表-C01900-Linda-20240129-(S)6000928456.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240129 7002179139 塑板螺絲 R89097\成本表-C01900-Linda-20240129-(D)7002179139.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240130 6000928720 塑板螺絲\成本表-C01900-Linda-20240130-(S)6000928720.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240130 6000928728 塑板螺絲 (專案906)\成本表-C01900-Linda-20240130-(S)6000928728.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240130 6000928753 乾牆螺絲(專案906.907.908)\成本表-C01900-Linda-20240130-(S)6000928753(專案906).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240130 6000928753 乾牆螺絲(專案906.907.908)\成本表-C01900-Linda-20240130-(S)6000928753(專案907).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240130 6000928753 乾牆螺絲(專案906.907.908)\成本表-C01900-Linda-20240130-(S)6000928753(專案908).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240130 7002179126 (客圖)\成本表-C01900-Linda-20240206-(D)7002179126.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240130 7002179589 機械螺絲 8.8級\成本表-C01900-Linda-20240131-(D)7002179589.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240130 7002179814 塑板螺絲\成本表-C01900-Wesley-20240130-(S)7002179814.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240130 7002179824 塑板螺絲\成本表-C01900-Wesley-20240131-(S)7002179824.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240131 7002180138 自攻.鑽尾\成本表-C01900-Linda-20240131-(D)7002180138.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240131 7002180420 機械螺絲 8.8級\成本表-C01900-Linda-20240131-(D)7002180420.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240206 7002183958 塑板螺絲 R88096\成本表-C01900-Linda-20240206-(D)7002183958.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240207 7002185379 塑板螺絲\成本表-C01900-Linda-20240207-(D)7002185379.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240215 6000930799 機械螺絲\成本表-C01900-Linda-20240215-(S)6000930799.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240215 7002188644 鑽尾螺絲 (袋裝)\成本表-C01900-Wesley-2024216-(D)7002188644.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240215 7002188765 塑板螺絲\成本表-C01900-Wesley-20240219-(S)7002188765.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240215 7002189161 塑板螺絲 R89097\成本表-C01900-Linda-20240215-(D)7002189161.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240216 6000931292 塑板螺絲 R89098\成本表-C01900-Wesley-20240216-(S)6000931292.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240216 7002189794 塑板螺絲 R89098\成本表-C01900-Wesley-20240216-(S)7002189794.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240220 7002191230 塑板螺絲 R89097\成本表-C01900-Wesley-20240220-(D)7002191230.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240220 7002191230 塑板螺絲 R89097\成本表-C01900-Wesley-20240220-(D)7002191230_opticalsorting.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240220 7002191439 機械螺絲 D965\成本表-C01900-Wesley-20240220-(S)7002191439.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240220 7002191602 塑板螺絲 R89096\成本表-C01900-Wesley-20240220-(D)7002191602.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240220 7002191723 D7504\成本表-C01900-Glove-20240220-(D)7002191723.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240222 7002193317 89097\成本表-C01900-Wesley-20240222-(D)7002193317.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240222 7002193328 DW 89150(906)\成本表-C01900-Wesley-20240222-(S)7002193328(專案906).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240223 6000932392 自攻 7983\成本表-C01900-Wesley-20240227-(D)6000932392.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240226 60000932397 DW(專案906.907.908)\成本表-C01900-Wesley-20240226-(S)6000932397_906.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240226 60000932397 DW(專案906.907.908)\成本表-C01900-Wesley-20240226-(S)6000932397_907.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240226 60000932397 DW(專案906.907.908)\成本表-C01900-Wesley-20240226-(S)6000932397_908.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240226 7002194810 DW  SDS(專案908)\成本表-C01900-Glove-20240227-(D)RFQ_7002194810.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240227 6000932586 塑板螺絲(專案907)\成本表-C01900-Wesley-20240227-(S)6000932586.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240227 7002194985 塑板螺絲\成本表-C01900-Wesley-20240227-(D)7002194985.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240227 7002195153 三角牙\成本表-C01900-Wesley-20240227-(D)7002195153.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240227 7002195193 自攻\成本表-C01900-Wesley-20240227-(D)7002195193.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240229 6000933019 三角牙 自攻 鑽尾\成本表-C01900-Wesley-20240229-(D)6000933019(三角牙).xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$1:$36.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240229 6000933019 三角牙 自攻 鑽尾\成本表-C01900-Wesley-20240229-(D)6000933019(自攻).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240229 6000933019 三角牙 自攻 鑽尾\成本表-C01900-Wesley-20240229-(D)6000933019(鑽尾).xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$1:$41.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240229 7002196899\成本表-C01900-Wesley-20240301-(S)7002196899.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240301 7002197240 89098\成本表-C01900-Ru-20240410-(S)7002197240.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240305 7002198113 (客圖)\成本表-C01900-RU-20240612-(D)7002198113.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240305 7002198167 三角牙\成本表-C01900-Wei-20240305-(D)7002198167.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$1:$8.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240306 7002200168 盤頭三角牙\成本表-C01900-Caysie-20240306-(D)7002200168.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240308 6000934062 機械螺絲\成本表-C01900-Wei-20240308-(S)6000934062.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240308 6000934328 機械螺絲\成本表-C01900-Wei-20240311-6000934328.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240308 7002200979 DW(專案906)\成本表-C01900-Wei-202400308-7002200979(專案906).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240308 7002201142 自攻(客圖)\成本表-C01900-Wesley-20240411-(S)7002201142.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240312 6000934489 塑板螺絲 R89096 R89097 R89098\成本表-C01900-Wei-20240312-(S)6000934489.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240315 7002205119 塑板螺絲\成本表-C01900-Ru-20240321-(S)7002205119.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240318 6000935387 三角牙 自攻 鑽尾\成本表-C01900-RURU-20240319-(S)6000935387三角牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240318 6000935387 三角牙 自攻 鑽尾\成本表-C01900-RURU-20240319-(S)6000935387自攻.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240318 6000935387 三角牙 自攻 鑽尾\成本表-C01900-RURU-20240319-(S)6000935387鑽尾.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240318 7002205908 三角牙\成本表-C01900-Wesley-20240318-(D)7002205908.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240319 7002206419 CB\成本表-C01900-Wei-20240319-(D)7002206419.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240320 7002207164 CB R89097\成本表-C01900-Wesley-20240320-(D)7002207164.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240322 6000936229 機械螺絲\成本表-C01900-Wesley-20240322-(S)6000936229.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240325 7002209718 鑽尾\成本表-C01900-Ru-2024326-(D)7002209718(鑽尾).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240325 7002209729 鑽尾\成本表-C01900-RURU-20240327-(S)7002209729鑽尾.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$1:$11.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240325 7002209879 機械螺絲\成本表-C01900-Ru-20240325-(S)7002209879.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240326 7002210794 機械螺絲\成本表-C01900-Ru-2024327-(S)7002210794.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240328 7002211437 機械螺絲\成本表-C01900-RU-20240328-(S)7002211437.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240328 7002211865 塑板螺絲R89096(待尺寸確認要不要報價)\成本表-C01900-Ru-20240328-(S)7002211865.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240329 7002212521 塑板螺絲\成本表-C01900-RU-20240329-(D)7002212521.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240402 7002212814 CB 89097\成本表-C019-Glave-20240402-7002212814 (差鍍鎳價格).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240402 7002212814 CB 89097\成本表-C01900-Wesley-20240402-(D)7002212814 - 複製.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240402 7002212814 CB 89097\成本表-C01900-Wesley-20240402-(D)7002212814.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240403 6000937536 三角牙 自攻\成本表-C01900-Caysie-20240411-(S)6000937536三角牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240403 6000937536 三角牙 自攻\成本表-C01900-Caysie-20240412-(S)6000937536自攻.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240403 7002213267 機械螺絲\成本表-C01900-Caysie-20240417-(D)7002213267.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240403 7002213267 機械螺絲\成本表-C01900-Wesley-20240408-(D)7002213267.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240408 7002213643 機械螺絲\成本表-C01900-Ru-20240408-(S)7002213643 MOQ加價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240408 7002213643 機械螺絲\成本表-C01900-Ru-20240408-(S)7002213643.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240408 7002214188 自攻螺絲\成本表-C01900-Caysie-20240408-(D)7002214188.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240408 7002214443 乾牆(專案906)\成本表-C01900-Caysie-20240408-(D)7002214443(專案906-RAPTOR).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240408 7002214443 乾牆(專案906)\成本表-C01900-Ru-20240408-(S)7002214443(專案906-RAPTOR).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240408 7002215352 鑽尾\成本表-C01900-Wesley-20240408-(D)7002215352.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$1:$8.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240408 7002215703 塑板螺絲\成本表-C01900-Ru-20240408-(S)7002215703.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240409 6000938403 機械螺絲\成本表-C01900-Caysie-20240409-(S)6000938403 .xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240409 6000938403 機械螺絲\成本表-C01900-RU-20240409-(S)6000938403.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240409 7002215699 塑板螺絲\成本表-C01900-Caysie-20240408-(D)7002215699.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240410 6000938467(專案906 907 908)\成本表-C01900-Caysie-20240410-(S)6000938467(專案906).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240410 6000938467(專案906 907 908)\成本表-C01900-Caysie-20240410-(S)6000938467(專案907).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240410 6000938467(專案906 907 908)\成本表-C01900-Caysie-20240410-(S)6000938467(專案908).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240411 6000938812 三角牙 自攻 鑽尾\成本表-C01900-Caysie-20240411-(S)6000938812三角牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240411 6000938812 三角牙 自攻 鑽尾\成本表-C01900-Caysie-20240411-(S)6000938812自攻.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240411 6000938812 三角牙 自攻 鑽尾\成本表-C01900-Caysie-20240411-(S)6000938812鑽尾.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240411 7002217698 自攻\成本表-C01900-Caysie-20240411-(S)7002217698自攻.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240411 7002217698 自攻\成本表-C01900-RURU-20240411-(S)7002217698自攻.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240411 7002217893 機械螺絲\成本表-C01900-Wesley-20240412-(S)7002217893.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240412 7002218161 機械螺絲\成本表-C01900-Wesley-20240412-(S)7002218161.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240415 7002218592 三角牙\成本表-C01900-Caysie-20240415-(D)7002218592.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240417 7002220133 機械螺絲\成本表-C01900-Caysie-20240417-(S)7002220133.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240418 7002220703 三角牙\成本表-C01900-RURU-20240419-(S)7002220703三角牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240418 7002220809 機械螺絲\成本表-C01900-RU-20240418-(S)7002220809.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240418 7002221097 CB\成本表-C01900-Caysie-20240418-(D)7002221097.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240419 700221442 SDS\成本表-C01900-Caysie-20240419-(D)70002221442鑽尾.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240422 6000940045 機械螺絲\成本表-C01900-Caysie-20240422-(S)6000940045機械 .xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240424 7002223658 塑板螺絲\成本表-C01900-Caysie-20240424-(D)7002223658.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240430 7002226421 塑板螺絲\成本表-C01900-Ru-20240430-(S)7002226421.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240430 7002226961 塑板螺絲\成本表-C01900-Caysie-20240430-(D)7002226961.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240430 7002227000 機械螺絲\成本表-C01900-Ru-20240430-(S)7002227000.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240502 6000941353乾牆螺絲(專案906)\成本表-C01900-Ru-20240502-(S)6000941353(專案906-RAPTOR).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240502 7002227712 自攻\成本表-C01900-Ru-20240502-(S)7002227712自攻.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240502 7002227888 三角牙\成本表-C01900-Caysie-20240502-(D)7002227888三角牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240503 6000941714(906.907.908專案)\成本表-C01900-Ru-20240503-(S)6000941714(專案906).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20240503 6000941714(906.907.908專案)\成本表-C01900-Ru-20240503-(S)6000941714(專案907).xlsx
#
#
# ...
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D04600 Boise Cascade\2024\REMAKE\成本表-D046-Rebecca-20230424-(E) wood screw 5LB plastic tub.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D04600 Boise Cascade\2024\REMAKE\成本表-D046-Rebecca-20230503-(E) 乾牆粗細牙 M數.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D04600 Boise Cascade\2024\REMAKE\成本表-D046-Rebecca-20230518-(E) 不銹鋼(BITx1).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D04600 Boise Cascade\2024\REMAKE\成本表-D046-Rebecca-20230829-(E) 乾牆粗細牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D04600 Boise Cascade\2024\REMAKE\成本表-D046-Rebecca-20231106-(E) 乾牆粗細牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D04600 Boise Cascade\2024\REMAKE\成本表-D046-Rebecca-20231206-(E) 乾牆粗細牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240108 Bri\成本表-D09000-Wesley-20240110-(E)Brittany(議價).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240108 Bri\成本表-D09000-Wesley-20240110-(E)Brittany.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240217 2月牌價\成本表-D09000-Wesley-20240217-(E)M_Bulk.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240217 2月牌價\成本表-D09000-Wesley-20240217-(E)Others.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240217 2月牌價\成本表-D09000-Wesley-20240318-(E)目標議價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240329\成本表-D09000-RU-20240329-(E)M_Bulk.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240329 Brittany(Doug)\成本表-D09000-RU-20240329-(E)Brittany.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240426 Bri\成本表-D09000-Wesley-20240426-(E)Brittany.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240603 Rob\成本表-D09000-Wesley-20240606-(E)Rob.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240611 Rob\成本表-D09000-Caysie-20240611-(E)SDS&DW.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240625 7 月牌價\成本表-D09000-Caysie-20240626-(E)月牌價 - deck.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240625 7 月牌價\成本表-D09000-Ruru-20240626-(E)月牌價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240625 ROB6-24-24\成本表-D09000-Ru-20240625-(E)ROB.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240625 ROB6-24-24-big\成本表-D09000-Caysie-20240625-(E)ROB-another - 更改包裝支數.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240625 ROB6-24-24-big\成本表-D09000-Caysie-20240625-(E)ROB-another.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240627 Rob追加品項\成本表-D09000-Wesley-20240627-(E)ROB-SDS.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240806 Bri\成本表-D09000-Wesley-20240806-(E)Brittany.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240821 Rob\成本表-D09000-Caysie-20240821-(E)Rob.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240828 Rob\成本表-D09000-Caysie-20240821-(E)Extra_items.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240923 Rachel Mail\成本表-D09000-Glave-20240923-(E).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20240924  ROB9-23-24\成本表-D09000-Wesley-20240924-(E)Rob.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20241008 Rachel\成本表-D09000-Wesley-20241008(E)Rachel.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\20241008 Rachel 直出競價\成本表-D09000-Wesley-20241008-(E)Rachel.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20230526-(E) 乾牆 - 有營業費用.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20230628-(D) 乾牆螺絲大包牌價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231013-(E) 屋頂六角華司頭螺絲 -利潤前.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231013-(E) 屋頂六角華司頭螺絲 -改箱數.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231020-(E) 鑽尾螺絲大包牌價 有營業費用.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231107-(E) 乾牆螺絲大包牌價 有營業費用.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231107-(E) 讚尾螺絲大包牌價 有營業費用.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231208-(D) 乾牆螺絲大包牌價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231208-(E) 讚尾螺絲大包牌價 有營業費用.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231211-(D) 乾牆螺絲大包牌價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231211-(E) 讚尾螺絲大包牌價 有營業費用.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231228-(D) 乾牆螺絲大包牌價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09000-A BMD\(( Price list-牌價表 ))---2019.4 月開始有回饋金1%\2024\REMAKE\成本表-D090-Rebecca-20231228-(E) 讚尾螺絲大包牌價 有營業費用.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240110\成本表-D09200-Wesley-20240110-(E)Steve.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240117_橘色產品影響改單\成本表-D09200-Wesley-20240117-(E)橘色重製.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240215 水泥板螺絲(客圖)\成本表-D09200-Wesley-20240215-(E)水泥螺絲樣品.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240221_321546木螺絲\成本表-D09200-Ru-20240528-(S)321546.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240221_321546木螺絲\成本表-D09200-Wesley-20240221-(S)321546.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240221_321556木螺絲\成本表-D09200-Ru-20240528-(S)321556.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240221_321556木螺絲\成本表-D09200-Wesley-20240221-(S)321556.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\202402牌價\成本表-D09200-Wesley-20240201-(S)clamshell.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\202402牌價\成本表-D09200-Wesley-20240201-(S)MF504FQ.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\202402牌價\成本表-D09200-Wesley-20240201-(S)MF506.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\202402牌價\成本表-D09200-Wesley-20240201-(S)PK970(停用).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\202402牌價\成本表-D09200-Wesley-20240201-(S)PK972.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\202402牌價\成本表-D09200-Wesley-20240201-(S)PK983.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\202402牌價\成本表-D09200-Wesley-20240201-(S)PK985.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240311_客製詢價\成本表-D09200-Wesley-20240311-(S)MF506.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240311_客製詢價(10U)\成本表-D09200-Wesley-20240313-(S)MF506.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240321_DW PROFIT\成本表-D09200-Wesley-20240321-(E)Tim.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240322 結構螺絲詢價\成本表-D09200-Wesley-20240329-(S)客圖結構螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240326 水泥板螺絲大貨價格\成本表-D09200-Wesley-20240326-(E)水泥螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240326_ DW PROFIT\成本表-D09200-Ruru-20240326-(E)Tim.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240327_DW PROFIT\成本表-D09200-Ruru-20240327-(E)Tim.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240401 truss screw #14x4-12\成本表-D09200-Wesley-20240404-(S)客圖結構螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240510 THD 水泥板螺絲報價\成本表-D09200-Glave-20240611-(E)水泥螺絲 - 包裝牌價更新.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240516 THD\成本表-D09200-Caysie-20240516-(E)THD.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240516 THD\成本表-D09200-Ruru-20240516-(E)乾牆.xlsx
# C:\Users\wesley\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:118: UserWarning: Print area cannot be set to Defined name: '成本表 '!$A:$AZ.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240516 THD\成本表-D09200-Wesley-20240516-(E)THD結構螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240522 乾牆粗細牙小蜜蜂鑽尾\成本表-D09200-Caysie-20240522-(E)Tim(總經理特裁係數).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240522 乾牆粗細牙小蜜蜂鑽尾\成本表-D09200-Caysie-20240522-(E)Tim.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240528 木螺絲 5月牌價\成本表-D09200-Caysie-20240528-(E)木螺絲月牌價(總經理特別牌價).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240528 木螺絲 5月牌價\成本表-D09200-Caysie-20240528-(E)木螺絲月牌價.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240617 THD-Deckmate4.0\成本表-D09200-Caysie-20240814-木螺絲 DECKMATE木螺絲-修正 - 1000小時.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240617 THD-Deckmate4.0\成本表-D09200-Caysie-20240814-木螺絲 DECKMATE木螺絲-修正.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240617 THD-Deckmate4.0\成本表-D09200-Caysie-20240814-木螺絲 大彩盒加國旗標-修正 - 1000小時.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240617 THD-Deckmate4.0\成本表-D09200-Caysie-20240814-木螺絲 大彩盒加國旗標-修正.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240617 THD-Deckmate4.0\成本表-D09200-Glave-20240729-DECKMATE木螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240617 THD-Deckmate4.0\成本表-D09200-Glave-20240729-木螺絲 大彩盒加國旗標.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240618 總經理特裁係數專案\成本表-D09200-Caysie-20240522-(E)Tim(總經理特裁係數).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240618 總經理特裁係數專案\成本表-D09200-Caysie-20240528-(E)木螺絲月牌價(總經理特別牌價).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240716 7月牌價(木螺絲+3支)\成本表-D09200-Caysie-20240716-(E)Tim(特裁).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\20240716 7月牌價(木螺絲+3支)\成本表-D09200-Caysie-20240716-(E)木螺絲月牌價(特裁).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\REMAKE\成本表-D092-Ray-20230710-(S)乾牆螺絲HomeDepot.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\REMAKE\成本表-D092-Ray-20230803-(S)屋頂螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\REMAKE\成本表-D092-Ray-20230807-(S)乾牆螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\REMAKE\成本表-D092-Ray-20230823-(S)結構螺絲_國旗標.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\REMAKE\成本表-D092-Ray-20230925-(S)不鏽鋼螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\REMAKE\成本表-D092-Ray-20231206-(S)水泥板螺絲.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09200 - National Nails 美國\2024\REMAKE\成本表-D092-Wesley-20191202-(S)大乾牆HomeDepot.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09300\2024\REMAKE\成本表-D093-Rebecca-20190701-(E) 乾牆螺絲粗細牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09300\2024\REMAKE\成本表-D093-Rebecca-20190911-(S) 乾牆螺絲粗細牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09300\2024\REMAKE\成本表-D093-Rebecca-20191017-(E) 乾牆螺絲粗細牙.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09400-美國 - FASTENING CARE\2024\REMAKE\成本表-D094-Rebecca-20230202-(E) 大包 M.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09400-美國 - FASTENING CARE\2024\REMAKE\成本表-D094-Rebecca-20230202-(E) 桶裝 25LB.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09400-美國 - FASTENING CARE\2024\REMAKE\成本表-D094-Rebecca-20230209-(E) 大包 M.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D09400-美國 - FASTENING CARE\2024\REMAKE\成本表-D094-Rebecca-20230605-(E) Wood DW SDS.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10000-美國 - Banner Sales\2024\REMAKE\成本表-D100-Rebecca-20230329-(E) 機械螺絲 六角頭華司(與舊格式差異-串華司設定的部份).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10100-美國 - Steel and Wire\2024\2024 1月牌價\成本表-D10100-Wesley-20240105-(E)Mike.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10100-美國 - Steel and Wire\2024\2024 2月牌價\成本表-D10100-Wesley-20240202-(E)Mike.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10100-美國 - Steel and Wire\2024\20240305 乾牆系列詢價\成本表-D10100-Linda-20240306-(S).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10100-美國 - Steel and Wire\2024\20240430 新增品項\成本表-D10100-Wesley-20240430-(E)Mike.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10100-美國 - Steel and Wire\2024\20240531 6月牌價\成本表-D10100-Wesley-20240531-(E)Mike.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10100-美國 - Steel and Wire\2024\20240729 8月牌價\成本表-D10100-Wesley-20240729-(E)Mike.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10600 Wildcat\2024\REMAKE\成本表-D106-Rebecca- 20221025-(E) 屋頂螺絲 (含頭噴).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10600 Wildcat\2024\REMAKE\成本表-D106-Rebecca- 20230605-(E) WildCat (美) 屋頂螺絲 無頭噴  (尖尾)  重包 先華司再利潤 (新增12x3) (新格式-不包含串華司利潤).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10600 Wildcat\2024\REMAKE\成本表-D106-Rebecca- 20230605-(E) WildCat (美) 屋頂螺絲 無頭噴  (尖尾) - 重包  先華司再利潤 (新格式-不包含串華司利潤).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10600 Wildcat\2024\REMAKE\成本表-D106-Rebecca- 20230605-(E) WildCat (美) 屋頂螺絲 無頭噴 (鑽尾) - 重包  先華司再利潤 (新格式-不包含串華司利潤).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10600 Wildcat\2024\REMAKE\成本表-D106-Rebecca- 20230815-(E) 屋頂螺絲 (含頭噴)(新格式-不包含串華司利潤).xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10700 Tacoma-美國\2024\REMAKE\成本表-D107-Rebecca-20230614-(E) 9200878-00.xlsx
#
#
# 此檔案未被記錄 : Z:/業務部/業務一課/G-報價/1. 外銷/D10700 Tacoma-美國\2024\REMAKE\成本表-D107-Rebecca-20231021-(E) SDS 9201107.xlsx

# %%
connection = sqlite3.connect("Z:\跨部門\共用資料夾\C. 業務部\詢價統計DB\QUOTATION_DATABASE.db")
query = "SELECT * FROM CUSTOMER_PRODUCT_SUMMARY" 
df = pd.read_sql_query(query, connection)
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 connection = sqlite3.connect("Z:\跨部門\共用資料夾\C. 業務部\詢價統計DB\QUOTATION_DATABASE.db")
#       2 query = "SELECT * FROM CUSTOMER_PRODUCT_SUMMARY"
#       3 df = pd.read_sql_query(query, connection)
#
# NameError: name 'sqlite3' is not defined

# %%
import pandas as pd 
import os 
import re 
import time
from datetime import datetime
import sqlite3

def UPDATEDB_BYFILE(DB,ROW_NAME) :
    with sqlite3.connect(DATABASE) as connection :
        cursor = connection.cursor()
        # delete old data
        cursor.execute(f"DELETE FROM PRODUCT_ADDRESS_SUMMARY WHERE FILE_ADDRESS ='{ROW_NAME}'")
        cursor.execute(f"DELETE FROM CUSTOMER_PRODUCT_SUMMARY WHERE ORDER_ADDRESS ='{ROW_NAME}'")

        #reload the data into DB
        PRODUCT_INFO, DATA_SUM, D1, D2, VER = READ_FILE(ROW_NAME)
        cursor.execute(f"INSERT INTO PRODUCT_ADDRESS_SUMMARY (FILE_ADDRESS) VALUES (?);"
                                        ,(ROW_NAME,)) # 檔案位置資料庫
        QUOTATION_INSERT(DATA_SUM, "CUSTOMER_PRODUCT_SUMMARY", "QUOTATION_DATABASE.db", cursor)

# %%
import unicodedata
DATABASE = r"Z:\跨部門\共用資料夾\C. 業務部\詢價統計DB\QUOTATION_DATABASE.db"
OBJECT = r"Z:/業務部/業務一課/G-報價/1. 外銷/C01900 Reyher\2024\20241107 6000966771 MS\成本表-C01900-Wesley-20241108-(S)6000966771.xlsx"
UPDATEDB_BYFILE(DATABASE, OBJECT)

# %%
import sqlite3
def UPDATEDB_BYAGENT(DB,AGENT_NAME) :
    with sqlite3.connect(DATABASE) as connection :
        cursor = connection.cursor()
        # delete old data
        cursor.execute(f"DELETE FROM PRODUCT_ADDRESS_SUMMARY WHERE FILE_ADDRESS LIKE ?", (f'%{AGENT_NAME}%',)) 
        cursor.execute(f"DELETE FROM CUSTOMER_PRODUCT_SUMMARY WHERE AGENT = '{AGENT_NAME}'")

# %%
address_ALL = pd.read_sql_query("SELECT * FROM PRODUCT_ADDRESS_SUMMARY")
print(address_ALL)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[28], line 14
#      11             print("Database integrity check failed:", result)
#      13 # Call this function to check the integrity
# ---> 14 check_db_integrity(DATABASE)
#
# Cell In[28], line 4, in check_db_integrity(DB)
#       3 def check_db_integrity(DB):
# ----> 4     with sqlite3.connect(DB) as connection:
#       5         cursor = connection.cursor()
#       6         cursor.execute('PRAGMA integrity_check;')
#
# OperationalError: unable to open database file
