# %%
import pandas as pd
data = pd.read_excel("雄台不良品-20241021.xlsx")
organixed_data = data[["線徑", "卷重"]].groupby("線徑").sum()
organixed_data
# Out:
#           卷重
# 線徑
# 2.60   641.0
# 2.65   339.0
# 2.70  1120.0
# 2.80   390.0
# 3.15   176.0
# 3.20  1609.0
# 3.30   906.0
# 3.37  1603.0
# 3.40   388.0
# 3.45   116.0
# 3.50   251.0
# 3.55  1217.0
# 3.70   888.0
# 4.20  1338.0
# 4.38    67.0
# 4.85    90.0
# 4.90    87.0
# 5.60   476.0
